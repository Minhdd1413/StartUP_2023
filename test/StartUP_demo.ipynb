# %% [markdown]
# ![Windows PowerShell 17_10_2023 6_41_43 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Tóm tắt mô hình detect
# ---
# - Đầu vào mô hình là một đoạn âm thanh
# - Đầu ra có thể tuỳ chọn được 2 loại data: giá trị dự đoán về tỉ lệ % khả năng người đó ho và có thể segment được giữa một đoạn recording phức tạp nhiều đoạn âm thanh cả ho lẫn không ho.
# - Link data dùng để test ở Terminal trên: https://drive.google.com/drive/folders/1gFUKgsKXZZbGlq8F5dNKf4P_GRns4V8R?usp=drive_link (not_cough.wav không thể segment ra được vì không có tiếng ho)
